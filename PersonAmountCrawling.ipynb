# %%
import requests
import urllib3
from urllib import parse
import pandas as pd
import re

urllib3.disable_warnings()
url = "https://27.101.213.4/downloadCsvAge.do?searchYearMonth=month&xlsStats=1"
headers = {
    "accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9",
    "accept-language": "ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7,ja-JP;q=0.6,ja;q=0.5,la;q=0.4,zh-TW;q=0.3,zh-CN;q=0.2,zh;q=0.1",
    "cache-control": "max-age=0",
    "content-type": "application/x-www-form-urlencoded",
    "sec-fetch-dest": "document",
    "sec-fetch-mode": "navigate",
    "sec-fetch-site": "same-origin",
    "sec-fetch-user": "?1",
    "upgrade-insecure-requests": "1",
}

data = {
    "sltOrgType": "1",
    "sltOrgLvl1": "A", # A | 비우기 (계)
    "sltOrgLvl2": "A", # A | 비우기 (남녀구분)
    "gender": "", # gender | 비우기
    'sum': "sum",
    "sltUndefType": "",
    "searchYearStart": "2020",
    "searchMonthStart": "12",
    "searchYearEnd": "2020",
    "searchMonthEnd": "12",
    "sltOrderType": "1",
    "sltOrderValue": "ASC",
    "sltArgTypes": "5",# 나이간격 1 / 5 / 10
    "sltArgTypeA": "0",
    "sltArgTypeB": "100",
    "category": "year",# month / year
    "state": "1",
    "stateMobile": "1"
}

res = requests.post(url=url, headers=headers, data=data, verify=False, stream=True)
res.raise_for_status()
res.encoding = 'euc-kr'

headerFileName = res.headers["Content-Disposition"];
fileName = re.findall("filename=(.+)", parse.unquote(headerFileName))[0]
fileName = fileName.replace("\"","").replace("\"","").replace(";","")
with open(fileName, 'wb') as f:
    f.write(res.content)
df = pd.read_csv(fileName, encoding='euc-kr', thousands = ',')

# %%
import requests
import urllib3
from urllib import parse
import pandas as pd
import re

urllib3.disable_warnings()
url = "https://kosis.kr/statHtml/downNormal.do"
headers = {
    "accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9",
    "accept-language": "ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7,ja-JP;q=0.6,ja;q=0.5,la;q=0.4,zh-TW;q=0.3,zh-CN;q=0.2,zh;q=0.1",
    "cache-control": "max-age=0",
    "content-type": "application/x-www-form-urlencoded",
    "sec-fetch-dest": "document",
    "sec-fetch-mode": "navigate",
    "sec-fetch-site": "same-origin",
    "sec-fetch-user": "?1",
    "upgrade-insecure-requests": "1",
}

data = {
    "orgId":101,
    "tblId":"DT_1PM1503",
    "language":"ko",
    "file":"%EC%97%B0%EB%A0%B9%EB%B3%84_%EC%84%B1%EB%B3%84_%ED%98%BC%EC%9D%B8%EC%83%81%ED%83%9C%EB%B3%84_%EC%9D%B8%EA%B5%AC_15%EC%84%B8%EC%9D%B4%EC%83%81_%EB%82%B4%EA%B5%AD%EC%9D%B8_%EC%8B%9C%EA%B5%B0%EA%B5%AC_20210209124800.csv",
    "analText":"",
    "scrId":"",
    "fieldList":"%5B%7B%22targetId%22%3A%22PRD%22%2C%22targetValue%22%3A%22%22%2C%22prdValue%22%3A%22F%2C2015%2C%40%22%7D%2C%7B%22targetId%22%3A%22ITM_ID%22%2C%22targetValue%22%3A%22T10%22%2C%22prdValue%22%3A%22%22%7D%2C%7B%22targetId%22%3A%22ITM_ID%22%2C%22targetValue%22%3A%22T11%22%2C%22prdValue%22%3A%22%22%7D%2C%7B%22targetId%22%3A%22ITM_ID%22%2C%22targetValue%22%3A%22T12%22%2C%22prdValue%22%3A%22%22%7D%2C%7B%22targetId%22%3A%22ITM_ID%22%2C%22targetValue%22%3A%22T13%22%2C%22prdValue%22%3A%22%22%7D%2C%7B%22targetId%22%3A%22ITM_ID%22%2C%22targetValue%22%3A%22T14%22%2C%22prdValue%22%3A%22%22%7D%2C%7B%22targetId%22%3A%22ITM_ID%22%2C%22targetValue%22%3A%22T20%22%2C%22prdValue%22%3A%22%22%7D%2C%7B%22targetId%22%3A%22ITM_ID%22%2C%22targetValue%22%3A%22T21%22%2C%22prdValue%22%3A%22%22%7D%2C%7B%22targetId%22%3A%22ITM_ID%22%2C%22targetValue%22%3A%22T22%22%2C%22prdValue%22%3A%22%22%7D%2C%7B%22targetId%22%3A%22ITM_ID%22%2C%22targetValue%22%3A%22T23%22%2C%22prdValue%22%3A%22%22%7D%2C%7B%22targetId%22%3A%22ITM_ID%22%2C%22targetValue%22%3A%22T24%22%2C%22prdValue%22%3A%22%22%7D%2C%7B%22targetId%22%3A%22ITM_ID%22%2C%22targetValue%22%3A%22T30%22%2C%22prdValue%22%3A%22%22%7D%2C%7B%22targetId%22%3A%22ITM_ID%22%2C%22targetValue%22%3A%22T31%22%2C%22prdValue%22%3A%22%22%7D%2C%7B%22targetId%22%3A%22ITM_ID%22%2C%22targetValue%22%3A%22T32%22%2C%22prdValue%22%3A%22%22%7D%2C%7B%22targetId%22%3A%22ITM_ID%22%2C%22targetValue%22%3A%22T33%22%2C%22prdValue%22%3A%22%22%7D%2C%7B%22targetId%22%3A%22ITM_ID%22%2C%22targetValue%22%3A%22T34%22%2C%22prdValue%22%3A%22%22%7D%2C%7B%22targetId%22%3A%22OV_L1_ID%22%2C%22targetValue%22%3A%2200%22%2C%22prdValue%22%3A%22%22%7D%2C%7B%22targetId%22%3A%22OV_L1_ID%22%2C%22targetValue%22%3A%2203%22%2C%22prdValue%22%3A%22%22%7D%2C%7B%22targetId%22%3A%22OV_L1_ID%22%2C%22targetValue%22%3A%2204%22%2C%22prdValue%22%3A%22%22%7D%2C%7B%22targetId%22%3A%22OV_L1_ID%22%2C%22targetValue%22%3A%2205%22%2C%22prdValue%22%3A%22%22%7D%2C%7B%22targetId%22%3A%22OV_L1_ID%22%2C%22targetValue%22%3A%2211%22%2C%22prdValue%22%3A%22%22%7D%2C%7B%22targetId%22%3A%22OV_L1_ID%22%2C%22targetValue%22%3A%2221%22%2C%22prdValue%22%3A%22%22%7D%2C%7B%22targetId%22%3A%22OV_L1_ID%22%2C%22targetValue%22%3A%2222%22%2C%22prdValue%22%3A%22%22%7D%2C%7B%22targetId%22%3A%22OV_L1_ID%22%2C%22targetValue%22%3A%2223%22%2C%22prdValue%22%3A%22%22%7D%2C%7B%22targetId%22%3A%22OV_L1_ID%22%2C%22targetValue%22%3A%2224%22%2C%22prdValue%22%3A%22%22%7D%2C%7B%22targetId%22%3A%22OV_L1_ID%22%2C%22targetValue%22%3A%2225%22%2C%22prdValue%22%3A%22%22%7D%2C%7B%22targetId%22%3A%22OV_L1_ID%22%2C%22targetValue%22%3A%2226%22%2C%22prdValue%22%3A%22%22%7D%2C%7B%22targetId%22%3A%22OV_L1_ID%22%2C%22targetValue%22%3A%2229%22%2C%22prdValue%22%3A%22%22%7D%2C%7B%22targetId%22%3A%22OV_L1_ID%22%2C%22targetValue%22%3A%2231%22%2C%22prdValue%22%3A%22%22%7D%2C%7B%22targetId%22%3A%22OV_L1_ID%22%2C%22targetValue%22%3A%2232%22%2C%22prdValue%22%3A%22%22%7D%2C%7B%22targetId%22%3A%22OV_L1_ID%22%2C%22targetValue%22%3A%2233%22%2C%22prdValue%22%3A%22%22%7D%2C%7B%22targetId%22%3A%22OV_L1_ID%22%2C%22targetValue%22%3A%2234%22%2C%22prdValue%22%3A%22%22%7D%2C%7B%22targetId%22%3A%22OV_L1_ID%22%2C%22targetValue%22%3A%2235%22%2C%22prdValue%22%3A%22%22%7D%2C%7B%22targetId%22%3A%22OV_L1_ID%22%2C%22targetValue%22%3A%2236%22%2C%22prdValue%22%3A%22%22%7D%2C%7B%22targetId%22%3A%22OV_L1_ID%22%2C%22targetValue%22%3A%2237%22%2C%22prdValue%22%3A%22%22%7D%2C%7B%22targetId%22%3A%22OV_L1_ID%22%2C%22targetValue%22%3A%2238%22%2C%22prdValue%22%3A%22%22%7D%2C%7B%22targetId%22%3A%22OV_L1_ID%22%2C%22targetValue%22%3A%2239%22%2C%22prdValue%22%3A%22%22%7D%2C%7B%22targetId%22%3A%22OV_L2_ID%22%2C%22targetValue%22%3A%22000%22%2C%22prdValue%22%3A%22%22%7D%2C%7B%22targetId%22%3A%22OV_L2_ID%22%2C%22targetValue%22%3A%22020%22%2C%22prdValue%22%3A%22%22%7D%2C%7B%22targetId%22%3A%22OV_L2_ID%22%2C%22targetValue%22%3A%22025%22%2C%22prdValue%22%3A%22%22%7D%2C%7B%22targetId%22%3A%22OV_L2_ID%22%2C%22targetValue%22%3A%22030%22%2C%22prdValue%22%3A%22%22%7D%2C%7B%22targetId%22%3A%22OV_L2_ID%22%2C%22targetValue%22%3A%22035%22%2C%22prdValue%22%3A%22%22%7D%2C%7B%22targetId%22%3A%22OV_L2_ID%22%2C%22targetValue%22%3A%22040%22%2C%22prdValue%22%3A%22%22%7D%2C%7B%22targetId%22%3A%22OV_L2_ID%22%2C%22targetValue%22%3A%22045%22%2C%22prdValue%22%3A%22%22%7D%2C%7B%22targetId%22%3A%22OV_L2_ID%22%2C%22targetValue%22%3A%22050%22%2C%22prdValue%22%3A%22%22%7D%2C%7B%22targetId%22%3A%22OV_L2_ID%22%2C%22targetValue%22%3A%22055%22%2C%22prdValue%22%3A%22%22%7D%2C%7B%22targetId%22%3A%22OV_L2_ID%22%2C%22targetValue%22%3A%22060%22%2C%22prdValue%22%3A%22%22%7D%2C%7B%22targetId%22%3A%22OV_L2_ID%22%2C%22targetValue%22%3A%22065%22%2C%22prdValue%22%3A%22%22%7D%2C%7B%22targetId%22%3A%22OV_L2_ID%22%2C%22targetValue%22%3A%22070%22%2C%22prdValue%22%3A%22%22%7D%2C%7B%22targetId%22%3A%22OV_L2_ID%22%2C%22targetValue%22%3A%22075%22%2C%22prdValue%22%3A%22%22%7D%2C%7B%22targetId%22%3A%22OV_L2_ID%22%2C%22targetValue%22%3A%22080%22%2C%22prdValue%22%3A%22%22%7D%2C%7B%22targetId%22%3A%22OV_L2_ID%22%2C%22targetValue%22%3A%22085%22%2C%22prdValue%22%3A%22%22%7D%2C%7B%22targetId%22%3A%22OV_L2_ID%22%2C%22targetValue%22%3A%22086%22%2C%22prdValue%22%3A%22%22%7D%5D",
    "colAxis":"TIME%2CITEM",
    "rowAxis":"A%2CB",
    "isFirst":"N",
    "contextPath":"%2FstatHtml",
    "ordColIdx":"",
    "ordType":"",
    "logSeq":100642127,
    "vwCd":"",
    "listId":"",
    "connPath":"",
    "statId":1962001,
    "pub":"",
    "pubLog":3,
    "viewKind":2,
    "viewSubKind":"",
    "doAnal":"N",
    "analType":"",
    "analCmpr":"",
    "analTime":"",
    "analCombo":"",
    "originData":"",
    "analClass":"",
    "analItem":"",
    "obj_var_id":"",
    "itm_id":"",
    "mode":"",
    "dataOpt":"ko",
    "noSelect":"",
    "view":"csv",
    "existStblCmmtKor":"Y",
    "existStblCmmtEng":"N",
    "classAllArr":"%5B%7B%22objVarId%22%3A%22A%22%2C%22ovlSn%22%3A%221%22%7D%2C%7B%22objVarId%22%3A%22B%22%2C%22ovlSn%22%3A%222%22%7D%5D",
    "classSet":"%5B%7B%22objVarId%22%3A%22A%22%2C%22ovlSn%22%3A%221%22%2C%22visible%22%3A%22true%22%7D%2C%7B%22objVarId%22%3A%22B%22%2C%22ovlSn%22%3A%222%22%2C%22visible%22%3A%22true%22%7D%5D",
    "selectAllFlag":"N",
    "selectTimeRangeCnt":1,
    "periodStr":"F",
    "funcPrdSe":"",
    "tblNm":"%EC%97%B0%EB%A0%B9%EB%B3%84%2F%EC%84%B1%EB%B3%84%2F%ED%98%BC%EC%9D%B8%EC%83%81%ED%83%9C%EB%B3%84+%EC%9D%B8%EA%B5%AC%2815%EC%84%B8%EC%9D%B4%EC%83%81%2C%EB%82%B4%EA%B5%AD%EC%9D%B8%29-%EC%8B%9C%EA%B5%B0%EA%B5%AC",
    "tblEngNm":"",
    "isChangedDataOpt":"",
    "itemMultiply":5040,
    "dimCo":"",
    "dbUser":"NSI.",
    "usePivot":"N",
    "isChangedTableType":"N",
    "isChangedPeriodCo":"N",
    "isChangedPrdSort":"N",
    "p_chkStatus":"",
    "p_objVarId":"",
    "p_lvl":"",
    "p_logicFlag":"Y",
    "p_classAllChkYn":"Y",
    "p_classAllSelectYn":"N",
    "useAddFuncLog":"",
    "chargerLvl":"",
    "st":"",
    "new_win":"",
    "first_open":"Y",
    "debug":"",
    "maxCellOver":"",
    "reqCellCnt":5040,
    "inheritYn":"N",
    "originOrgId":"",
    "originTblId":"",
    "pubSeType":"",
    "relChkOrgId":"",
    "relChkTblId":"",
    "highLightStr":"",
    "markType":"",
    "docId":"",
    "itmNm":"",
    "tableType":"default",
    "dataOpt2":"ko",
    "periodCo":"",
    "prdSort":"desc",
    "findData":"on",
    "compValue":"",
    "compValue01":"",
    "compValue02":"",
    "downGridFileType":"csv",
    "downSort":"asc",
    "pointType":"screen",
    "downLargeFileType":"excel",
    "downLargeExprType":1,
    "downLargeSort":"asc",
    "naviInfo":"tabItemText",
    "naviInfo":"A",
    "naviInfo":"B",
    "naviInfo":"tabTimeText",
    "itemChkLi":"T10",
    "itemChkLi":"T11",
    "itemChkLi":"T12",
    "itemChkLi":"T13",
    "itemChkLi":"T14",
    "itemChkLi":"T20",
    "itemChkLi":"T21",
    "itemChkLi":"T22",
    "itemChkLi":"T23",
    "itemChkLi":"T24",
    "itemChkLi":'T30',
    "itemChkLi":"T31",
    "itemChkLi":"T32",
    "itemChkLi":"T33",
    "itemChkLi":"T34",
    "classLvlAllChk1_2":"on",
    "classChkLi1_1":"00%3D",
    "defaultFolder":1,
    "classChkLi1_1":"03%3D",
    "defaultFolder":1,
    "classChkLi1_1":"04%3D",
    "defaultFolder":1,
    "classChkLi1_1":"05%3D",
    "defaultFolder":1,
    "classChkLi1_1":"11%3D",
    "defaultFolder":0,
    "classChkLi1_1":"21%3D",
    "defaultFolder":0,
    "classChkLi1_1":"22%3D",
    "defaultFolder":0,
    "classChkLi1_1":"23%3D",
    "defaultFolder":0,
    "classChkLi1_1":"24%3D",
    "defaultFolder":0,
    "classChkLi1_1":"25%3D",
    "defaultFolder":0,
    "classChkLi1_1":"26%3D",
    "defaultFolder":0,
    "classChkLi1_1":"29%3D",
    "defaultFolder":0,
    "classChkLi1_1":"31%3D",
    "defaultFolder":0,
    "classChkLi1_1":"32%3D",
    "defaultFolder":0,
    "classChkLi1_1":"33%3D",
    "defaultFolder":0,
    "classChkLi1_1":"34%3D",
    "defaultFolder":0,
    "classChkLi1_1":"35%3D",
    "defaultFolder":0,
    "classChkLi1_1":"36%3D",
    "defaultFolder":0,
    "classChkLi1_1":"37%3D",
    "defaultFolder":0,
    "classChkLi1_1":"38%3D",
    "defaultFolder":0,
    "classChkLi1_1":"39%3D",
    "defaultFolder":0,
    "classLvlAllChk2_2":"on",
    "classChkLi2_1":"000%3D",
    "defaultFolder":1,
    "classChkLi2_1":"020%3D",
    "defaultFolder":0,
    "classChkLi2_1":"025%3D",
    "defaultFolder":0,
    "classChkLi2_1":"030%3D",
    "defaultFolder":0,
    "classChkLi2_1":"035%3D",
    "defaultFolder":0,
    "classChkLi2_1":"040%3D",
    "defaultFolder":0,
    "classChkLi2_1":"045%3D",
    "defaultFolder":0,
    "classChkLi2_1":"050%3D",
    "defaultFolder":0,
    "classChkLi2_1":"055%3D",
    "defaultFolder":0,
    "classChkLi2_1":"060%3D",
    "defaultFolder":0,
    "classChkLi2_1":"065%3D",
    "defaultFolder":0,
    "classChkLi2_1":"070%3D",
    "defaultFolder":0,
    "classChkLi2_1":"075%3D",
    "defaultFolder":0,
    "classChkLi2_1":"080%3D",
    "defaultFolder":0,
    "classChkLi2_1":"085%3D",
    "defaultFolder":0,
    "classChkLi2_1":"086%3D",
    "defaultFolder":1,
    "headCheck":"F",
    "timeChkF":2015,
}

res = requests.post(url=url, headers=headers, data=data, verify=False, stream=True)
res.raise_for_status()
res.encoding = "euc-kr"

with open("혼인상태별.csv", "wb") as f:
    f.write(res.content)
df2 = pd.read_csv("혼인상태별.csv", encoding="euc-kr", thousands = ",")
# df2 = df.transpose() # 행,열 교차 변환
print(df2)
# Out:
#                      행정구역  2020년12월_계_총인구수  2020년12월_계_연령구간인구수  \
# 0        전국  (0000000000)         51829023            51829023
# 1     서울특별시  (1100000000)          9668465             9668465
# 2     부산광역시  (2600000000)          3391946             3391946
# 3     대구광역시  (2700000000)          2418346             2418346
# 4     인천광역시  (2800000000)          2942828             2942828
# 5     광주광역시  (2900000000)          1450062             1450062
# 6     대전광역시  (3000000000)          1463882             1463882
# 7     울산광역시  (3100000000)          1136017             1136017
# 8   세종특별자치시  (3600000000)           355831              355831
# 9       경기도  (4100000000)         13427014            13427014
# 10      강원도  (4200000000)          1542840             1542840
# 11     충청북도  (4300000000)          1600837             1600837
# 12     충청남도  (4400000000)          2121029             2121029
# 13     전라북도  (4500000000)          1804104             1804104
# ...
