# %%
import xml.etree.ElementTree as ET
import requests

lifeArray = ("001","002","003","004","005","006")
charTrgterArray = ("001","002","003","004","005","006")
obstKiArray = ("10","20","30","40","50","60","70","80","90","A0","B0","C0","D0","E0","F0")
obstLvArray = ("1","2","3","4","5","6")
trgterIndvdlArray = ("001","002","003","004","005","006","007")
desireArray = ("0000000","1000000","2000000","3000000","4000000","5000000","6000000","7000000","8000000","9000000","A000000")
crtiKey = "GEWhKkN9XljjmritytmGqGYFwKNgW4JjFnV1Ry0plpBSuljX1mNhjKXJRFzc8bKhTJEwWZHpd6f9yAnlAYxzog%3D%3D"

lifeContent = ""
charTrgterContent = ""
obstKiContent = ""
obstLvContent = ""
trgterIndvdlContent = ""
desireContent = ""

for lifeItem in lifeArray:
    for charTrgterItem in charTrgterArray:
        if charTrgterItem == "004":
            for obstKiItem in obstKiArray:
                for obstLvItem in obstLvArray:
                    for trgterIndvdlItem in trgterIndvdlArray:
                        for desireItem in desireArray:
                            i = 0
                            while i < 1000:
                                endPoint = "http://www.bokjiro.go.kr/openapi/rest/gvmtWelSvc?crtiKey={0}&callTp=L&pageNo={1}&numOfRows=100&lifeArray={2}&charTrgterArray={3}&obstKiArray={4}&obstLvArray={5}&trgterIndvdlArray={6}&desireArray={7}".format(crtiKey, (i+1), lifeItem, charTrgterItem, obstKiItem, obstLvItem, trgterIndvdlItem, desireItem)
                                res = requests.get(endPoint)
                                if res.status_code == 200:
                                    root = ET.fromstring(res.text)
                                    tree = ET.ElementTree(root)
                                    if 0 == int(tree.find('totalCount').text):
                                        i = 1000
                                    elif (i) * 1000 < int(tree.find('totalCount').text):
                                        pass
                                    else:
                                        i = 1000
                                    if i != 1000:
                                        if lifeItem == "001":
                                            lifeContent = "영유아"
                                        elif lifeItem == "002":
                                            lifeContent = "아동"
                                        elif lifeItem == "003":
                                            lifeContent = "청소년"
                                        elif lifeItem == "004":
                                            lifeContent = "청년"
                                        elif lifeItem == "005":
                                            lifeContent = "중장년"
                                        elif lifeItem == "006":
                                            lifeContent = "노년"
                                        if charTrgterItem == "001":
                                            charTrgterContent = "해당없음"
                                        elif charTrgterItem == "002":
                                            charTrgterContent = "여성"
                                        elif charTrgterItem == "003":
                                            charTrgterContent = "임산부"
                                        elif charTrgterItem == "004":
                                            charTrgterContent = "장애"
                                        elif charTrgterItem == "005":
                                            charTrgterContent = "국가유공자등_보훈대상자"
                                        elif charTrgterItem == "006":
                                            charTrgterContent = "실업자"
                                        if obstKiItem == "10":
                                            obstKiContent = "지체"
                                        elif obstKiItem == "20":
                                            obstKiContent = "시각"
                                        elif obstKiItem == "30":
                                            obstKiContent = "청각"
                                        elif obstKiItem == "40":
                                            obstKiContent = "언어"
                                        elif obstKiItem == "50":
                                            obstKiContent = "지적"
                                        elif obstKiItem == "60":
                                            obstKiContent = "뇌병변"
                                        elif obstKiItem == "70":
                                            obstKiContent = "자폐성"
                                        elif obstKiItem == "80":
                                            obstKiContent = "정신"
                                        elif obstKiItem == "90":
                                            obstKiContent = "신장"
                                        elif obstKiItem == "A0":
                                            obstKiContent = "심장"
                                        elif obstKiItem == "B0":
                                            obstKiContent = "호흡기"
                                        elif obstKiItem == "C0":
                                            obstKiContent = "간"
                                        elif obstKiItem == "D0":
                                            obstKiContent = "안면"
                                        elif obstKiItem == "E0":
                                            obstKiContent = "장루"
                                        elif obstKiItem == "F0":
                                            obstKiContent = "간질"
                                        if obstLvItem == "1":
                                            obstLvContent = "1급"
                                        elif obstLvItem == "2":
                                            obstLvContent = "2급"
                                        elif obstLvItem == "3":
                                            obstLvContent = "3급"
                                        elif obstLvItem == "4":
                                            obstLvContent = "4급"
                                        elif obstLvItem == "5":
                                            obstLvContent = "5급"
                                        elif obstLvItem == "6":
                                            obstLvContent = "6급"
                                        if trgterIndvdlItem == "001":
                                            trgterIndvdlContent = "해당없음"
                                        elif trgterIndvdlItem == "002":
                                            trgterIndvdlContent = "한부모"
                                        elif trgterIndvdlItem == "003":
                                            trgterIndvdlContent = "다문화"
                                        elif trgterIndvdlItem == "004":
                                            trgterIndvdlContent = "조손"
                                        elif trgterIndvdlItem == "005":
                                            trgterIndvdlContent = "새터민"
                                        elif trgterIndvdlItem == "006":
                                            trgterIndvdlContent = "소년소녀가장"
                                        elif trgterIndvdlItem == "007":
                                            trgterIndvdlContent = "독거노인"
                                        if desireItem == "0000000":
                                            desireContent = "안전"
                                        elif desireItem == "1000000":
                                            desireContent = "건강"
                                        elif desireItem == "2000000":
                                            desireContent = "일상생활유지"
                                        elif desireItem == "3000000":
                                            desireContent = "가족관계"
                                        elif desireItem == "4000000":
                                            desireContent = "사회적관계"
                                        elif desireItem == "5000000":
                                            desireContent = "경제"
                                        elif desireItem == "6000000":
                                            desireContent = "교육"
                                        elif desireItem == "7000000":
                                            desireContent = "고용"
                                        elif desireItem == "8000000":
                                            desireContent = "생활환경"
                                        elif desireItem == "9000000":
                                            desireContent = "법률및권익보장"
                                        elif desireItem == "A000000":
                                            desireContent = "기타"
                                        print(lifeContent, charTrgterContent, obstKiContent, obstLvContent, trgterIndvdlContent, desireContent, (i+1))
                                        tree.write("collections/{0}_{1}_{2}_{3}_{4}_{5}_{6}.xml".format(lifeContent, charTrgterContent, obstKiContent, obstLvContent, trgterIndvdlContent, desireContent, (i+1)), encoding="UTF-8", xml_declaration=True)
                                else:
                                    print(res.status_code)
                                i += 1
        else:
            for trgterIndvdlItem in trgterIndvdlArray:
                for desireItem in desireArray:
                    i = 0
                    while i < 1000:
                        endPoint = "http://www.bokjiro.go.kr/openapi/rest/gvmtWelSvc?crtiKey={0}&callTp=L&pageNo={1}&numOfRows=100&lifeArray={2}&charTrgterArray={3}&trgterIndvdlArray={4}&desireArray={5}".format(crtiKey, (i+1), lifeItem, charTrgterItem, trgterIndvdlItem, desireItem)
                        res = requests.get(endPoint)
                        if res.status_code == 200:
                            root = ET.fromstring(res.text)
                            tree = ET.ElementTree(root)
                            if 0 == int(tree.find('totalCount').text):
                                i = 1000
                            elif (i) * 1000 < int(tree.find('totalCount').text):
                                pass
                            else:
                                i = 1000
                            if i != 1000:
                                if lifeItem == "001":
                                    lifeContent = "영유아"
                                elif lifeItem == "002":
                                    lifeContent = "아동"
                                elif lifeItem == "003":
                                    lifeContent = "청소년"
                                elif lifeItem == "004":
                                    lifeContent = "청년"
                                elif lifeItem == "005":
                                    lifeContent = "중장년"
                                elif lifeItem == "006":
                                    lifeContent = "노년"
                                if charTrgterItem == "001":
                                    charTrgterContent = "해당없음"
                                elif charTrgterItem == "002":
                                    charTrgterContent = "여성"
                                elif charTrgterItem == "003":
                                    charTrgterContent = "임산부"
                                elif charTrgterItem == "004":
                                    charTrgterContent = "장애"
                                elif charTrgterItem == "005":
                                    charTrgterContent = "국가유공자등_보훈대상자"
                                elif charTrgterItem == "006":
                                    charTrgterContent = "실업자"
                                if trgterIndvdlItem == "001":
                                    trgterIndvdlContent = "해당없음"
                                elif trgterIndvdlItem == "002":
                                    trgterIndvdlContent = "한부모"
                                elif trgterIndvdlItem == "003":
                                    trgterIndvdlContent = "다문화"
                                elif trgterIndvdlItem == "004":
                                    trgterIndvdlContent = "조손"
                                elif trgterIndvdlItem == "005":
                                    trgterIndvdlContent = "새터민"
                                elif trgterIndvdlItem == "006":
                                    trgterIndvdlContent = "소년소녀가장"
                                elif trgterIndvdlItem == "007":
                                    trgterIndvdlContent = "독거노인"
                                if desireItem == "0000000":
                                    desireContent = "안전"
                                elif desireItem == "1000000":
                                    desireContent = "건강"
                                elif desireItem == "2000000":
                                    desireContent = "일상생활유지"
                                elif desireItem == "3000000":
                                    desireContent = "가족관계"
                                elif desireItem == "4000000":
                                    desireContent = "사회적관계"
                                elif desireItem == "5000000":
                                    desireContent = "경제"
                                elif desireItem == "6000000":
                                    desireContent = "교육"
                                elif desireItem == "7000000":
                                    desireContent = "고용"
                                elif desireItem == "8000000":
                                    desireContent = "생활환경"
                                elif desireItem == "9000000":
                                    desireContent = "법률및권익보장"
                                elif desireItem == "A000000":
                                    desireContent = "기타"
                                print(lifeContent, charTrgterContent, trgterIndvdlContent, desireContent, (i+1))
                                tree.write("collections/{0}_{1}_{2}_{3}_{4}.xml".format(lifeContent, charTrgterContent, trgterIndvdlContent, desireContent, (i+1)), encoding="UTF-8", xml_declaration=True)
                        else:
                            print(res.status_code)
                        i += 1
